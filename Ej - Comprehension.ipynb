# %% [markdown]
# ## Ej Modulo 10 - Comprehension

# %%
import requests

print("Lista de Reproducción\n")
print("Ingresa la palabra que te gustaría buscar en canciones o artistas (Ejemplo: 'rock'):")

word_to_search = input("Buscar: ")

url = "https://deezerdevs-deezer.p.rapidapi.com/search"
querystring = {"q": word_to_search}
headers = {
    "X-RapidAPI-Key": "3ed98f551fmshe4e6260228c4eadp13db17jsn8c893e1194da",
    "X-RapidAPI-Host": "deezerdevs-deezer.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring).json()

# Generar una lista de diccionarios con artista y canción
my_list = [{"artista": song["artist"]["name"], "canción": song["title"]}
           for song in response.get("data", [])]

# Resultados
print("\n🎧 Resultados encontrados:\n")
for index, item in enumerate(my_list, start=1):
    print(f"{index}. {item['artista']} - {item['canción']}")
# Out:
# Lista de Reproducción
#
# Ingresa la palabra que te gustaría buscar en canciones o artistas (Ejemplo: 'rock'):
# Buscar:  rock
# 🎧 Resultados encontrados:
#
# 1. Post Malone - rockstar
# 2. Justin Timberlake - Rock Your Body
# 3. Elton John - Rocket Man (I Think It's Going To Be A Long, Long Time)
# 4. DaBaby - ROCKSTAR
# 5. The Clash - Rock the Casbah (Remastered)
# 6. Kiss - Rock And Roll All Nite
# 7. Rockwell - Somebody's Watching Me
# 8. Clean Bandit - Rockabye (feat. Sean Paul & Anne-Marie)
# 9. Scorpions - Rock You Like a Hurricane (2011)
# 10. Boston - Rock & Roll Band
# 11. Bob Sinclar - Rock This Party (Everybody Dance Now)
# 12. LISA - Rockstar
# 13. AC/DC - Rock N Roll Train
# 14. The Velvet Underground - Rock & Roll (Full Length Version; 2015 Remaster)
# 15. R3HAB - Rock My Body
# 16. Stepz - Rock
# 17. Plies - Rock
# 18. Michael Jackson - Rock With You
# 19. BigXthaPlug - Rock & Roll
# 20. The Subways - Rock & Roll Queen
# 21. Buffalo Springfield - Rock & Roll Woman
# ...

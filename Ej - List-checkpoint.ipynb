# %%
print("Carrito de compras/n")

print("""
Productos Disponibles

1.- Pan
2.- Jamón
3.- Crema
4.- Mayonesa
5.- Lechuga
6.- Chocolate
7.- Almendras
8.- Leche
""")

print("Ingresa una lista con los productos en este formato: [[Cantidad, Producto]]")
print("Por ejemplo: [[1, 1], [3, 2]] significa 1 Pan y 3 Jamón")

my_shoopping_cart = eval(input())

print("\n\nTu carrito es.")
if type(my_shoopping_cart) == list:
    if type(my_shoopping_cart[0]) == list:
        for element in my_shoopping_cart:
            product = ""
            if element[1] == 1:
                product = "Pan"
            if element[1] == 2:
                product = "Jamón"
            if element[1] == 3:
                product = "Crema"
            if element[1] == 4:
                product = "Mayonesa"
            if element[1] == 5:
                product = "Lechuga"
            if element[1] == 6:
                product = "Chocolate"
            if element[1] == 7:
                product = "Almendras"
            if element[1] == 8:
                product = "Leche"

            print("{} {}".format(element[0], product))
    else:
        print("Formato incorrecto, debes ingresar una lista de listas")
else:
    print("Formato incorrecto, debes ingresar una lista de listas")
# Out:
# Carrito de compras/n
#
# Productos Disponibles
#
# 1.- Pan
# 2.- Jamón
# 3.- Crema
# 4.- Mayonesa
# 5.- Lechuga
# 6.- Chocolate
# 7.- Almendras
# 8.- Leche
#
# Ingresa una lista con los productos en este formato: [[Cantidad, Producto]]
# Por ejemplo: [[1, 1], [3, 2]] significa 1 Pan y 3 Jamón
#  [[1, 6], [3, 8]]
# Tu carrito es.
# 1 Chocolate
# 3 Leche

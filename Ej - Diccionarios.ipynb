# %%
# !pip install pokebase
# Out:
# Collecting pokebase
#   Downloading pokebase-1.4.1-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: requests in c:\users\saems\anaconda3\lib\site-packages (from pokebase) (2.32.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\saems\anaconda3\lib\site-packages (from requests->pokebase) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\saems\anaconda3\lib\site-packages (from requests->pokebase) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\saems\anaconda3\lib\site-packages (from requests->pokebase) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\saems\anaconda3\lib\site-packages (from requests->pokebase) (2024.7.4)
# Downloading pokebase-1.4.1-py3-none-any.whl (11 kB)
# Installing collected packages: pokebase
# Successfully installed pokebase-1.4.1

# %%
import pokebase as pb
import requests

pokemon_to_search = input("Ingresa el nombre de un Pokémon\n\n")

data = pb.pokemon(pokemon_to_search).__dict__
id_ = data.get('id_')
name = data.get('name')
height = data.get('height')   # ← Altura
weight = data.get('weight')   # ← Peso

print("ID: ", id_)
print("Nombre: ", name)
print("Altura: ", height)
print("Peso: ", weight)

url = "https://pokeapi.co/api/v2/characteristic/{id}/".format(id=id_)
response = requests.get(url)

for description_dict in response.json().get("descriptions"):
    if description_dict.get("language", {}).get("name") == "es":
        description = description_dict.get("description")
        print("Descripción: ", description)
